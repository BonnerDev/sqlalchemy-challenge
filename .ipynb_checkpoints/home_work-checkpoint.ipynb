# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
 # Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect,func

# %%
Base = automap_base()
engine = create_engine("sqlite:///hawaii.sqlite")
conn = engine.connect()

# %%
 # reflect an existing database into a new model
Base.prepare(engine, reflect=True)
# reflect the tables

# %%
 # We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
 # Save references to each table
Station=Base.classes.station
Measurement=Base.classes.measurement

# %%
 # Create our session (link) from Python to the DB
session=Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
 # Use Inspector to print the column names and types
columns = inspector.get_columns('Measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
columns = inspector.get_columns('Station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
data=pd.read_sql("select * from Measurement inner join Station on (Measurement.station = Station.station)",conn)
data
# Out:
#           id      station        date  prcp  tobs  id      station  \
# 0          1  USC00519397  2010-01-01  0.08  65.0   1  USC00519397
# 1          2  USC00519397  2010-01-02  0.00  63.0   1  USC00519397
# 2          3  USC00519397  2010-01-03  0.00  74.0   1  USC00519397
# 3          4  USC00519397  2010-01-04  0.00  76.0   1  USC00519397
# 4          5  USC00519397  2010-01-06   NaN  73.0   1  USC00519397
# ...      ...          ...         ...   ...   ...  ..          ...
# 19545  19546  USC00516128  2017-08-19  0.09  71.0   9  USC00516128
# 19546  19547  USC00516128  2017-08-20   NaN  78.0   9  USC00516128
# 19547  19548  USC00516128  2017-08-21  0.56  76.0   9  USC00516128
# 19548  19549  USC00516128  2017-08-22  0.50  76.0   9  USC00516128
# 19549  19550  USC00516128  2017-08-23  0.45  76.0   9  USC00516128
#
#                                name  latitude  longitude  elevation
# 0              WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 1              WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 2              WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 3              WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 4              WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# ...                             ...       ...        ...        ...
# 19545  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19546  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19547  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19548  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19549  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
#
# [19550 rows x 11 columns]

# %%
to_datetime=pd.to_datetime(data['date'])
to_datetime
# Out:
# 0       2010-01-01
# 1       2010-01-02
# 2       2010-01-03
# 3       2010-01-04
# 4       2010-01-06
#            ...
# 19545   2017-08-19
# 19546   2017-08-20
# 19547   2017-08-21
# 19548   2017-08-22
# 19549   2017-08-23
# Name: date, Length: 19550, dtype: datetime64[ns]

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

# Calculate the date 1 year ago from the last data point in the database
#fnd the date for the last point
last_point=session.query(Measurement.date).order_by(Measurement.date.desc()).first()
#print to find the last point
last_point

#then find the date 1 year before this date 
year_before = dt.date(2017, 8, 23) - dt.timedelta(days=365)
year_before
# Out:
# datetime.date(2016, 8, 23)

# %%
date_df=data[(data['date']<='2017-08-23')&(data['date']>"2016-08-23")]
date_df
# Out:
#           id      station        date  prcp  tobs  id      station  \
# 2364    2365  USC00519397  2016-08-24  0.08  79.0   1  USC00519397
# 2365    2366  USC00519397  2016-08-25  0.08  80.0   1  USC00519397
# 2366    2367  USC00519397  2016-08-26  0.00  79.0   1  USC00519397
# 2367    2368  USC00519397  2016-08-27  0.00  77.0   1  USC00519397
# 2368    2369  USC00519397  2016-08-28  0.01  78.0   1  USC00519397
# ...      ...          ...         ...   ...   ...  ..          ...
# 19545  19546  USC00516128  2017-08-19  0.09  71.0   9  USC00516128
# 19546  19547  USC00516128  2017-08-20   NaN  78.0   9  USC00516128
# 19547  19548  USC00516128  2017-08-21  0.56  76.0   9  USC00516128
# 19548  19549  USC00516128  2017-08-22  0.50  76.0   9  USC00516128
# 19549  19550  USC00516128  2017-08-23  0.45  76.0   9  USC00516128
#
#                                name  latitude  longitude  elevation
# 2364           WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 2365           WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 2366           WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 2367           WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# 2368           WAIKIKI 717.2, HI US   21.2716  -157.8168        3.0
# ...                             ...       ...        ...        ...
# 19545  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19546  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19547  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19548  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
# 19549  MANOA LYON ARBO 785.2, HI US   21.3331  -157.8025      152.4
#
# [2223 rows x 11 columns]

# %%
# Perform a query to retrieve the data and precipitation scores
data_prcp_df = pd.DataFrame(date_df)
#data_prcp_df
# Save the query results as a Pandas DataFrame and set the index to the date column
new_df=data_prcp_df[['date','prcp']]
indexed=(new_df.groupby('date').sum())
indexed
# Sort the dataframe by date
#new_df=pd.DataFrame(indexed)
df_sorted =indexed.sort_values('date',ascending=True)
df_sorted
# Out:
#             prcp
# date
# 2016-08-24  9.33
# 2016-08-25  0.54
# 2016-08-26  0.10
# 2016-08-27  0.32
# 2016-08-28  3.10
# ...          ...
# 2017-08-19  0.09
# 2017-08-20  0.01
# 2017-08-21  0.58
# 2017-08-22  0.50
# 2017-08-23  0.53
#
# [365 rows x 1 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
df_sorted.plot(use_index=True,y="prcp")
plt.xticks(rotation=90)
plt.ylabel("Precipitation")
# Out:
# Text(0, 0.5, 'Precipitation')

# %%
 # Use Pandas to calcualte the summary statistics for the precipitation data
df_sorted.describe()
# Out:
#              prcp
# count  365.000000
# mean     0.974164
# std      1.776466
# min      0.000000
# 25%      0.050000
# 50%      0.400000
# 75%      1.080000
# max     14.280000

# %%
 # Design a query to show how many stations are available in this dataset?
station_active=session.query(Station.station).count()
station_active
# Out:
# 9

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
meas=pd.read_sql("select * from Measurement",conn)
stat=pd.read_sql("select * from Station",conn)
join = meas.merge(stat,on='station',how='left')
unique_join=join['station'].unique()
nun_join=unique_join['station'].nunique()
print(nun_join,unique_join)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-280-bf5c4722f2b9> in <module>
#       5 join = meas.merge(stat,on='station',how='left')
#       6 unique_join=join['station'].unique()
# ----> 7 nun_join=unique_join['station'].nunique()
#       8 print(nun_join,unique_join)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?
lowest_emp = session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs))

# %%
 # Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

# %% [markdown]
# # Bonus Challenge Assignment

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))

# %%
 # Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.

# %%
 # Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)

# %%
# Calculate the total amount of rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date

# %%
 # Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index

# %%
# Plot the daily normals as an area plot with `stacked=False`
